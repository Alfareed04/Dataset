# %%
data = [("United States","US",40,44,42,126),
("China","CHN",40,27,24,91),
("Japan","JPN",20,12,13,45),
("Australia","AUS",18,19,16,53),
("France","FRA",16,26,22,64),
("Netherlands","NED",15,7,12,34),
("Great Britain","GBG",14,22,29,65),
("South Korea","KOR",13,9,10,32),
("Italy","ITA",12,13,15,40),
("Germany","GER",12,13,8,33),
("New Zealand","NZ",10,7,3,20)
]

columns = ["Country","Code","Gold","Silver","Bronze","Total"]
df = spark.createDataFrame(data=data, schema = columns)

df.printSchema()
df.show(truncate=False)
# Out:
# StatementMeta(, c51df918-b261-447d-87b5-8ed4d9d213c5, 3, Finished, Available, Finished)
# root
#  |-- Country: string (nullable = true)
#  |-- Code: string (nullable = true)
#  |-- Gold: long (nullable = true)
#  |-- Silver: long (nullable = true)
#  |-- Bronze: long (nullable = true)
#  |-- Total: long (nullable = true)
#
# +-------------+----+----+------+------+-----+
# |Country      |Code|Gold|Silver|Bronze|Total|
# +-------------+----+----+------+------+-----+
# |United States|US  |40  |44    |42    |126  |
# |China        |CHN |40  |27    |24    |91   |
# |Japan        |JPN |20  |12    |13    |45   |
# |Australia    |AUS |18  |19    |16    |53   |
# |France       |FRA |16  |26    |22    |64   |
# |Netherlands  |NED |15  |7     |12    |34   |
# |Great Britain|GBG |14  |22    |29    |65   |
# |South Korea  |KOR |13  |9     |10    |32   |
# |Italy        |ITA |12  |13    |15    |40   |
# |Germany      |GER |12  |13    |8     |33   |
# |New Zealand  |NZ  |10  |7     |3     |20   |
# +-------------+----+----+------+------+-----+

# %%
type (df)
# Out:
# StatementMeta(, c51df918-b261-447d-87b5-8ed4d9d213c5, 4, Finished, Available, Finished)
# pyspark.sql.dataframe.DataFrame

# %%
from pyspark.sql.types import StructType,StructField, StringType, IntegerType

data = [("United States","US",40,44,42,126),
("China","CHN",40,27,24,91),
("Japan","JPN",20,12,13,45),
("Australia","AUS",18,19,16,53),
("France","FRA",16,26,22,64),
("Netherlands","NED",15,7,12,34),
("Great Britain","GBG",14,22,29,65),
("South Korea","KOR",13,9,10,32),
("Italy","ITA",12,13,15,40),
("Germany","GER",12,13,8,33),
("New Zealand","NZ",10,7,3,20)
]

columns = StructType([ 
    StructField("Country", StringType(),True),
    StructField("Code", StringType(),True),
    StructField("Gold", IntegerType(), True),
    StructField("Sliver", IntegerType(), True),
    StructField("Bronze", IntegerType(), True),
    StructField("Total", IntegerType(), True)
    ])

df = spark.createDataFrame(data=data, schema = columns)

df.printSchema()
df.show(truncate=False)
# Out:
# StatementMeta(, c51df918-b261-447d-87b5-8ed4d9d213c5, 10, Finished, Available, Finished)
# root
#  |-- Country: string (nullable = true)
#  |-- Code: string (nullable = true)
#  |-- Gold: integer (nullable = true)
#  |-- Sliver: integer (nullable = true)
#  |-- Bronze: integer (nullable = true)
#  |-- Total: integer (nullable = true)
#
# +-------------+----+----+------+------+-----+
# |Country      |Code|Gold|Sliver|Bronze|Total|
# +-------------+----+----+------+------+-----+
# |United States|US  |40  |44    |42    |126  |
# |China        |CHN |40  |27    |24    |91   |
# |Japan        |JPN |20  |12    |13    |45   |
# |Australia    |AUS |18  |19    |16    |53   |
# |France       |FRA |16  |26    |22    |64   |
# |Netherlands  |NED |15  |7     |12    |34   |
# |Great Britain|GBG |14  |22    |29    |65   |
# |South Korea  |KOR |13  |9     |10    |32   |
# |Italy        |ITA |12  |13    |15    |40   |
# |Germany      |GER |12  |13    |8     |33   |
# |New Zealand  |NZ  |10  |7     |3     |20   |
# +-------------+----+----+------+------+-----+

# %%
columns_ddl="Country STRING, Code STRING, Gold INT,Silver INT,Bronze INT, Total INT"
df_with_ddl_schema = spark.createDataFrame(data=data,schema=columns_ddl)
df.printSchema()
df.show(truncate=False)
# Out:
# StatementMeta(, c51df918-b261-447d-87b5-8ed4d9d213c5, 11, Finished, Available, Finished)
# root
#  |-- Country: string (nullable = true)
#  |-- Code: string (nullable = true)
#  |-- Gold: integer (nullable = true)
#  |-- Sliver: integer (nullable = true)
#  |-- Bronze: integer (nullable = true)
#  |-- Total: integer (nullable = true)
#
# +-------------+----+----+------+------+-----+
# |Country      |Code|Gold|Sliver|Bronze|Total|
# +-------------+----+----+------+------+-----+
# |United States|US  |40  |44    |42    |126  |
# |China        |CHN |40  |27    |24    |91   |
# |Japan        |JPN |20  |12    |13    |45   |
# |Australia    |AUS |18  |19    |16    |53   |
# |France       |FRA |16  |26    |22    |64   |
# |Netherlands  |NED |15  |7     |12    |34   |
# |Great Britain|GBG |14  |22    |29    |65   |
# |South Korea  |KOR |13  |9     |10    |32   |
# |Italy        |ITA |12  |13    |15    |40   |
# |Germany      |GER |12  |13    |8     |33   |
# |New Zealand  |NZ  |10  |7     |3     |20   |
# +-------------+----+----+------+------+-----+

# %%
df.show()
# Out:
# StatementMeta(, c51df918-b261-447d-87b5-8ed4d9d213c5, 12, Finished, Available, Finished)
# +-------------+----+----+------+------+-----+
# |      Country|Code|Gold|Sliver|Bronze|Total|
# +-------------+----+----+------+------+-----+
# |United States|  US|  40|    44|    42|  126|
# |        China| CHN|  40|    27|    24|   91|
# |        Japan| JPN|  20|    12|    13|   45|
# |    Australia| AUS|  18|    19|    16|   53|
# |       France| FRA|  16|    26|    22|   64|
# |  Netherlands| NED|  15|     7|    12|   34|
# |Great Britain| GBG|  14|    22|    29|   65|
# |  South Korea| KOR|  13|     9|    10|   32|
# |        Italy| ITA|  12|    13|    15|   40|
# |      Germany| GER|  12|    13|     8|   33|
# |  New Zealand|  NZ|  10|     7|     3|   20|
# +-------------+----+----+------+------+-----+

# %%
display(df)
# Out:
# StatementMeta(, c51df918-b261-447d-87b5-8ed4d9d213c5, 13, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 559f44ec-8ca3-48a9-9337-8d3829ff369e)

# %%
display(df.head(2))
# Out:
# StatementMeta(, c51df918-b261-447d-87b5-8ed4d9d213c5, 14, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 7efe694c-eab6-4057-a136-43383932efff)

# %%
display(df.tail(5))
# Out:
# StatementMeta(, c51df918-b261-447d-87b5-8ed4d9d213c5, 15, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, c18b0be6-bba8-4e0f-a18f-1e995f5bfb93)

# %%
df.schema
# Out:
# StatementMeta(, c51df918-b261-447d-87b5-8ed4d9d213c5, 17, Finished, Available, Finished)
# StructType([StructField('Country', StringType(), True), StructField('Code', StringType(), True), StructField('Gold', IntegerType(), True), StructField('Sliver', IntegerType(), True), StructField('Bronze', IntegerType(), True), StructField('Total', IntegerType(), True)])
